# %%
from unittest.mock import inplace

import pandas as pd
import missingno as msno

# %%
movies = pd.read_csv('tmdb_movies.csv')

# %%
movies.head()
# Out:
#    Unnamed: 0     budget                                      homepage  \
# 0           0  237000000                   http://www.avatarmovie.com/
# 1           1  300000000  http://disney.go.com/disneypictures/pirates/
# 2           2  245000000   http://www.sonypictures.com/movies/spectre/
# 3           3  250000000            http://www.thedarkknightrises.com/
# 4           4  260000000          http://movies.disney.com/john-carter
#
#        id original_language                            original_title  \
# 0   19995                en                                    Avatar
# 1     285                en  Pirates of the Caribbean: At World's End
# 2  206647                en                                   Spectre
# 3   49026                en                     The Dark Knight Rises
# 4   49529                en                               John Carter
#
#                                             overview  popularity release_date  \
# ...

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'budget', 'homepage', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'release_date', 'revenue',
#        'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count',
#        'genre_id'],
#       dtype='object')

# %%
movies.rename(columns={'Unnamed: 0':'Id'}, inplace=True)

# %%
genderes = pd.read_csv('tmdb_genres.csv', skiprows=0)

# %%
genderes.head()
# Out:
#    Unnamed: 0           genres
# 0        28.0           Action
# 1        12.0        Adventure
# 2        14.0          Fantasy
# 3        16.0        Animation
# 4       878.0  Science Fiction

# %%
genderes.rename(columns={'Unnamed: 0':'Id'}, inplace=True)

# %%
df_movies = pd.DataFrame(movies)
df_genres = pd.DataFrame(genderes)

# %%
df_genres[df_genres['Id'].isnull()]
# Out:
#     Id genres
# 19 NaN    NaN

# %%
msno.matrix(df_movies)
# Out:
# <Axes: >

# %%
df_movies[df_movies['genre_id'].isnull()]
# Out:
#         Id   budget                            homepage      id  \
# 3971  3971        0                                 NaN  191229
# 3992  3992        0                                 NaN  346081
# 4068  4068        0                                 NaN  371085
# 4105  4105  2000000                                 NaN   48382
# 4118  4118        0                                 NaN  325140
# 4293  4293        1        http://thealgerianmovie.com/  357834
# 4314  4314  1200000                                 NaN  137955
# 4385  4385        0                                 NaN  206412
# 4400  4400        0                                 NaN  219716
# 4413  4413        0                                 NaN  335874
# 4458  4458        0                                 NaN  279759
# 4504  4504        0                                 NaN  331493
# 4550  4550        0                                 NaN  294550
# 4553  4553        0                                 NaN  380097
# ...

# %%
df_movies['release_date'] = pd.to_datetime(df_movies['release_date'])

# %%
df_movies[df_movies['release_date'].isnull()]
# Out:
#         Id  budget homepage      id original_language  \
# 4553  4553       0      NaN  380097                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      release_date  revenue  runtime    status tagline  \
# 4553          NaT        0      0.0  Released     NaN
#
#                            title  vote_average  vote_count  genre_id
# 4553  America Is Still the Place           0.0           0       NaN

# %%
df_movies.groupby(pd.Grouper(key='release_date', freq='y')).agg({'revenue':'sum'})
# Out:
# C:\Users\szcze\AppData\Local\Temp\ipykernel_20732\3058649957.py:1: FutureWarning: 'y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_movies.groupby(pd.Grouper(key='release_date', freq='y')).agg({'revenue':'sum'})
#                   revenue
# release_date
# 1916-12-31        8394751
# 1917-12-31              0
# 1918-12-31              0
# 1919-12-31              0
# 1920-12-31              0
# ...                   ...
# 2013-12-31    23411493295
# 2014-12-31    24120490589
# 2015-12-31    22775024221
# 2016-12-31    14461156948
# 2017-12-31              0
#
# [102 rows x 1 columns]
