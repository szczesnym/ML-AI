# %%
import numpy as np
import pandas as pd
from dash import Input

# przekształcanie – normalizacja danych
from sklearn.preprocessing import MinMaxScaler

# wizualizacja
import matplotlib.pyplot as plt

# sieci neuronowe
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU

# ewaluacja modelu
from sklearn.metrics import mean_squared_error

# %%
dataset = pd.read_csv('airline-passengers.csv')
dataset['Month'] = pd.to_datetime(dataset['Month'])
dataset.set_index(['Month'], inplace=True)
dataset
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
plt.figure(figsize=(16,9))
plt.plot(dataset['Passengers'])
plt.show()

# %%
train_size = int(len(dataset) * 0.70)
scaler = MinMaxScaler(feature_range=(0, 1))
look_back = 3
def create_dataset(df, train_size, lback=look_back, scaler_function=scaler):
    test_size = len(df) - train_size
    train, test = df[0:train_size,:].copy(), df[train_size:len(df),:].copy()
    train = scaler_function.fit_transform(train)
    test = scaler_function.transform(test)
    X_train, X_test, y_train, y_test = [], [], [], []

    # Tworzenie zbioru treninowego
    for i in range(len(train)-lback-1):
        a = train[i:(i+lback), 0]
        X_train.append(a)
        y_train.append(train[i + lback, 0])

    # Tworzenie zbioru testowego
    for i in range(len(test)-lback-1):
        a = test[i:(i+lback), 0]
        X_test.append(a)
        y_test.append(test[i + lback, 0])

    X_train, X_test = np.array(X_train), np.array(X_test)
    X_train, X_test = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1])), np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
    y_train, y_test = np.array(y_train), np.array(y_test)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = create_dataset(df=np.array(dataset), train_size=train_size, lback=look_back)

# %%
def backtests(model, lback=look_back):

    # predykcja - train
    prediction_train = scaler.inverse_transform(model.predict(X_train))
    prediction_train = pd.Series(prediction_train.flatten(),
                                index=dataset.index[lback:len(prediction_train)+lback])

    # predykcja - test
    prediction_test = scaler.inverse_transform(model.predict(X_test))
    prediction_test = pd.Series(prediction_test.flatten(),
                                index=dataset.index[len(prediction_train)+(2*lback)+1:len(dataset)-1])

    # wizualizacja prognozy
    plt.figure(figsize=(16,9))
    plt.plot(dataset['Passengers'], color='blue', label='True values')
    plt.plot(prediction_train, color='green', label='Prediction - Train')
    plt.plot(prediction_test, color='red', label='Prediction - Test')
    plt.legend(loc='upper left')
    plt.show()

    # obliczenie RMSE
    rmse = mean_squared_error(dataset.loc[prediction_test.index, :], prediction_test) ** 0.5
    print(f'\nRMSE TEST: {rmse}')

backtests(model_rnn)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# RMSE TEST: 64.4898323502434

# %%
model_rnn = Sequential()
model_rnn.add(Input(shape=(1, look_back)))
model_rnn.add(SimpleRNN(5))
model_rnn.add(Dense(1))
model_rnn.compile(loss='mean_squared_error', optimizer='adam')
model_rnn.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1)
# Out:
# Epoch 1/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 667us/step - loss: 0.4595
# Epoch 2/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - loss: 0.1313
# Epoch 3/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 0.0675
# Epoch 4/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - loss: 0.0524
# Epoch 5/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0425
# Epoch 6/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.0345
# Epoch 7/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 0.0273
# Epoch 8/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0221
# Epoch 9/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0180
# Epoch 10/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 0.0153
# Epoch 11/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0131
# Epoch 12/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0120
# Epoch 13/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0109
# Epoch 14/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.0104
# Epoch 15/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.0099
# Epoch 16/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.0099
# Epoch 17/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.0096
# Epoch 18/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.0095
# Epoch 19/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - loss: 0.0094
# Epoch 20/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 0.0090
# Epoch 21/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0089
# Epoch 22/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0087
# Epoch 23/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0087
# Epoch 24/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - loss: 0.0088
# Epoch 25/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.0085
# Epoch 26/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.0083
# Epoch 27/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0082
# Epoch 28/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.0082
# Epoch 29/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.0081
# Epoch 30/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.0077
# Epoch 31/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.0077
# Epoch 32/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.0072
# Epoch 33/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.0077
# Epoch 34/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.0073
# Epoch 35/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.0070
# Epoch 36/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 0.0066
# Epoch 37/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.0073
# Epoch 38/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.0070
# Epoch 39/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0068
# Epoch 40/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.0066
# Epoch 41/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0067
# Epoch 42/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0068
# Epoch 43/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.0067
# Epoch 44/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.0066
# Epoch 45/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 0.0065
# Epoch 46/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.0065
# Epoch 47/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0064
# Epoch 48/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - loss: 0.0062
# Epoch 49/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.0067
# Epoch 50/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0061
# Epoch 51/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.0060
# Epoch 52/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.0061
# Epoch 53/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 0.0059
# Epoch 54/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - loss: 0.0062
# Epoch 55/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0058
# Epoch 56/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.0062
# Epoch 57/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.0062
# Epoch 58/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0058
# Epoch 59/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.0059
# Epoch 60/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0058
# Epoch 61/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 0.0059
# Epoch 62/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.0062
# Epoch 63/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.0058
# Epoch 64/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0057
# Epoch 65/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.0060
# Epoch 66/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.0057
# Epoch 67/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.0060
# Epoch 68/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.0055
# Epoch 69/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0060
# Epoch 70/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 0.0057
# Epoch 71/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.0058
# Epoch 72/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 0.0057
# Epoch 73/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.0055
# Epoch 74/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.0054
# Epoch 75/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.0060
# Epoch 76/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0055
# Epoch 77/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0055
# Epoch 78/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.0055
# Epoch 79/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0059
# Epoch 80/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0057
# Epoch 81/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.0055
# Epoch 82/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.0056
# Epoch 83/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0056
# Epoch 84/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0057
# Epoch 85/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.0055
# Epoch 86/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0055
# Epoch 87/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.0058
# Epoch 88/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - loss: 0.0059
# Epoch 89/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.0053
# Epoch 90/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.0053
# Epoch 91/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 0.0053
# Epoch 92/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.0054
# Epoch 93/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - loss: 0.0053
# Epoch 94/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0054
# Epoch 95/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.0053
# Epoch 96/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.0052
# Epoch 97/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 0.0055
# Epoch 98/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0052
# Epoch 99/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0055
# Epoch 100/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0053
# Epoch 101/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.0055
# Epoch 102/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.0054
# Epoch 103/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - loss: 0.0056
# Epoch 104/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - loss: 0.0052
# Epoch 105/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0055
# Epoch 106/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0055
# Epoch 107/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.0052
# Epoch 108/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - loss: 0.0053
# Epoch 109/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0060
# Epoch 110/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - loss: 0.0053
# Epoch 111/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0052
# Epoch 112/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0058
# Epoch 113/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.0052
# Epoch 114/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.0052
# Epoch 115/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.0055
# Epoch 116/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.0058
# Epoch 117/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0053
# Epoch 118/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0055
# Epoch 119/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.0053
# Epoch 120/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0052
# Epoch 121/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.0056
# Epoch 122/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.0055
# Epoch 123/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.0053
# Epoch 124/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - loss: 0.0052
# Epoch 125/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.0051
# Epoch 126/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - loss: 0.0054
# Epoch 127/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0054
# Epoch 128/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0053
# Epoch 129/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0054
# Epoch 130/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0052
# Epoch 131/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.0051
# Epoch 132/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.0054
# Epoch 133/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - loss: 0.0051
# Epoch 134/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.0058
# Epoch 135/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0054
# Epoch 136/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.0052
# Epoch 137/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0052
# Epoch 138/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.0053
# Epoch 139/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.0054
# Epoch 140/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - loss: 0.0054
# Epoch 141/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 0.0051
# Epoch 142/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 0.0050
# Epoch 143/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.0055
# Epoch 144/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.0052
# Epoch 145/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - loss: 0.0057
# Epoch 146/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.0053
# Epoch 147/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - loss: 0.0052
# Epoch 148/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0052
# Epoch 149/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0053
# Epoch 150/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0052
# Epoch 151/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - loss: 0.0053
# Epoch 152/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0053
# Epoch 153/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0053
# Epoch 154/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.0053
# Epoch 155/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 0.0055
# Epoch 156/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.0049
# Epoch 157/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.0052
# Epoch 158/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0052
# Epoch 159/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.0051
# Epoch 160/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.0054
# Epoch 161/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0055
# Epoch 162/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.0054
# Epoch 163/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.0052
# Epoch 164/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.0052
# Epoch 165/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - loss: 0.0055
# Epoch 166/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - loss: 0.0054
# Epoch 167/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.0052
# Epoch 168/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.0053
# Epoch 169/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.0052
# Epoch 170/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.0053
# Epoch 171/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.0049
# Epoch 172/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.0055
# Epoch 173/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - loss: 0.0051
# Epoch 174/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.0054
# Epoch 175/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - loss: 0.0052
# Epoch 176/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0055
# Epoch 177/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.0052
# Epoch 178/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.0053
# Epoch 179/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - loss: 0.0053
# Epoch 180/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0052
# Epoch 181/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.0052
# Epoch 182/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 0.0052
# Epoch 183/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0052
# Epoch 184/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0050
# Epoch 185/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.0054
# Epoch 186/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 0.0056
# Epoch 187/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.0054
# Epoch 188/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0053
# Epoch 189/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.0052
# Epoch 190/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step - loss: 0.0051
# Epoch 191/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0052
# Epoch 192/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.0054
# Epoch 193/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0052
# Epoch 194/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.0053
# Epoch 195/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.0052
# Epoch 196/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.0053
# Epoch 197/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.0052
# Epoch 198/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.0055
# Epoch 199/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.0052
# Epoch 200/200
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.0051
